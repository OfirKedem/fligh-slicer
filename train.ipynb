# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Work/flight_slicer/
# Out:
# /content/drive/MyDrive/Work/flight_slicer

# %%
# %pip install comet-ml pytorch-lightning
# Out:
# ...
#      |████████████████████████████████| 342 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 527 kB 46.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 551 kB 40.1 MB/s
# ...
#      |████████████████████████████████| 829 kB 42.0 MB/s
# ...
#      |████████████████████████████████| 398 kB 43.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 41.1 MB/s
# ...
#      |████████████████████████████████| 952 kB 39.5 MB/s
# ...
#      |████████████████████████████████| 134 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 35.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 45.3 MB/s
# ...
#      |████████████████████████████████| 94 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 144 kB 41.3 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=91335aa460aa7a95d2f5b3caf094d644b075214fcfb16baec7c5bc28f4947545
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["COMET_API_KEY"] =

# %%
from train import train

train()
# Out:
# Global seed set to 42
# CometLogger will be initialized in online mode
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/ofirkedem/flight-slicer/c311b4eadadb45c7b6a48971592f0637
#
# COMET WARNING: truncated string; too long: 'VGG11(
#   (conv_layers): Sequential(
#     (0): Conv1d(2, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (4): ReLU()
# ...
