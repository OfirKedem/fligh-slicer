# %%
import numpy as np

from data.utils import generate_data
from viz.utils import plot_route

from infer import DeepSlicer


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = generate_data(n_routs_range=(100, 101),
                    n_spiral_range=(400,401))
net = DeepSlicer("flight-slicer/a191707048954a8098765c88878d5a3e/checkpoints/epoch=294-step=1474.ckpt")

# %%
idx = np.random.randint(len(data))
curr_data = data[idx]

print(len(curr_data['x']))

plot_route(**curr_data)
# Out:
# 600

# %%
idx = np.random.randint(len(data))
curr_data = data[idx]

pred = net(curr_data['x'], curr_data['y'])
print(pred)

start_diff = np.abs(pred[0] - curr_data['start'])
end_diff = np.abs(pred[1] - curr_data['end'])

print(f'start_diff: {start_diff}')
print(f'end_diff: {end_diff}')

plot_route(curr_data['x'], curr_data['y'], pred[0], pred[1])
# Out:
# [155 808]
# start_diff: 55
# end_diff: 308
